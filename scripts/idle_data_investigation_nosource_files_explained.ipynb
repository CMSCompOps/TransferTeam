# %% [markdown]
# # Understanding the idle data investigation script
#
# This script produces a list of files that have no source (no replica). The files are identified by taking a look at blocks associated with basis value of -6 (at least one file in the block has no source replica remaining) for a specific site. The blocks are retrieved using PhEDEx API (https://cmsweb.cern.ch/phedex/datasvc/doc/blockarrive).
#
# These files are mostly responsible for the piling of idle data from subscriptions to different sites (https://cmsweb.cern.ch/phedex/prod/Activity::QueuePlots?graph=idle&entity=dest&dest_filter=T0%7CT1%7CT2_CH_CERN&no_mss=true&period=l12h&upto=&.submit=Update).
#
# The script recovers all the blocks related to specific site subscriptions, then retrieves the responsible files. It checks their creation date. Produces a report of the datasets involve and in which extent are they affected (files with no source/ total files in the dataset and distribution across the dataset blocks ).
#
# A list of the files separated for each "type" ( whether they are 'data', 'mc' ... ) is generated. This list is intended to be used to proceed with global invalidation or for further investigation, depending on the type.
#
# If all the files of a block or dataset have no source. A file with a list of such blocks and a file with a list of such datasets are generated. These lists can facilitate the invalidation process to be performed in bulk instead of by files. Additionally, a list of files with no source is generated, excluding the files that are listed in the block list or datasets list. A list including the whole set of files per type is also generated.
#
# Finally, a search for deletions subscriptions related to the involved blocks is perform. A file concatenating the information pulled is generated. Until now, there hasn't been any case in which a deletion request is found. In case this starts happening the script functionality should be extended.

# %%
import json
import pandas as pd
from pandas.io.json import json_normalize
import requests
from requests.packages.urllib3.exceptions import InsecureRequestWarning
from datetime import datetime, timedelta
import re

# %%
from IPython.display import display

# %%
#Silent warnings of insecure request from requests library
requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

# %%
def dataset_from_blockname(blockname):
    '''
    prety simple function to get the dataset name having the block name
    '''
    return re.search('(.+)#', blockname).group(1)

# %%
def check_datetime_Xweeks_older (timestamp, nweeks):
    '''
    checks if timestamp is older than certain amount of weeks
    '''
    time_limit = datetime.now() - timedelta(weeks=nweeks)
    return datetime.fromtimestamp(timestamp) <= time_limit

# %%
def get_nosource_files_info(block):
    '''
    Seerch replicas for a given block and return the files that have no replica at all "[]" in replica field. 
    The returned value is a dictionary having a panda data frame with the metainfo of the block,
    the count of non  source files and the total number of files for the block
    Only the files with a creation time of more than 1 week are reported
    '''
    url = 'https://cmsweb.cern.ch/phedex/datasvc/json/prod/filereplicas'
    params = {"block": block}
    replicas_info = requests.get(url=url, params=params, verify=False).content
    replicas_json = json.loads(replicas_info)
    replicas_table = json_normalize(
        replicas_json['phedex']['block'][0]['file'])

    # Discards row entries of files with a creation date of one week or less
    replicas_table = replicas_table[replicas_table['time_create'].apply(
        check_datetime_Xweeks_older, nweeks=1) == True]

    num_files_in_block = len(replicas_table)
    no_source_files_table = replicas_table.loc[
        replicas_table.astype(str)['replica'] == "[]"]
    num_nosource_files_in_block = len(no_source_files_table)
    
    return {'df': no_source_files_table,
            'num_files_in_block': num_files_in_block,
            'num_nosource_files_in_block': num_nosource_files_in_block}

# %% [markdown]
# ### Example of `get_nosource_files_info( block )`

# %%
example_block = '/BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c960820-8625-11e6-b16f-02163e0184a6'
example_ns_files_info = get_nosource_files_info(example_block)
display(example_ns_files_info['df'])
print 'Number of non-source files: {} of {}'.format(example_ns_files_info['num_nosource_files_in_block'],
                                                    example_ns_files_info['num_files_in_block'])
# Out:
#          bytes                           checksum         id  \
# 0   2480029510  adler32:b26c6dd3,cksum:1405059702  101458476
# 2   2446225392  adler32:637d2e73,cksum:3564716832  101460134
# 3   2492112257  adler32:52ce435c,cksum:2214022121  101463210
# 6   2387554713  adler32:28874f74,cksum:1531599078  101482960
# 11  2322897779  adler32:5cc6c949,cksum:1101638021  101487218
# 13  3397572478  adler32:3d945dc3,cksum:4160566198  101511084
# 14  2359316290   adler32:da333a33,cksum:522016462  101483764
# 15  2381648457  adler32:d2053c21,cksum:1710051829  101479006
# 16  2383272277  adler32:8bc8cfc7,cksum:2568201960  101478547
# 17  2428671269  adler32:c02906d2,cksum:3865174811  101464007
# 18  2284817253  adler32:70760b0a,cksum:3620367416  101503289
# 21  2348248012  adler32:ca8bd11d,cksum:1013251246  101490245
# 23  2561919683  adler32:0a952185,cksum:3710306270  101510333
# 24  2360996621   adler32:8df61486,cksum:397336793  101492674
# 25  2242282930  adler32:b1916896,cksum:1322389979  101496415
# 26  2411078493  adler32:5e10ade7,cksum:1043591874  101475141
# 28  2519191679   adler32:e835d8ce,cksum:869109351  101513545
# 30  2337340518  adler32:66ac705f,cksum:2364421772  101493587
# 31  2346435413   adler32:bda26c8e,cksum:814785190  101485808
# 35  2284485682  adler32:0994ff8d,cksum:1853346002  101507464
# 39  2289788578  adler32:335a90b9,cksum:1958765787  101506238
# 40  2324108968  adler32:067dd98b,cksum:1168199932  101489251
# 42  2229046282   adler32:54b13f72,cksum:123517567  101497448
# 43  3505222995   adler32:7f06f8ea,cksum:712941224  101492054
# 44  2514467037  adler32:caf974e1,cksum:3992066838  101510841
# 46  2439297959  adler32:4d196d8b,cksum:3783968185  101482925
# 47  2411966479  adler32:45c7e841,cksum:2327251435  101472604
# 49  2454100010   adler32:6c289104,cksum:619024169  101471094
# 50  2330195082   adler32:10aca824,cksum:680891312  101457012
# 51  2437390592  adler32:a7543b91,cksum:4057095438  101481575
# 52  2273343719  adler32:d3004ad5,cksum:3685305564  101510549
#
#                                                  name original_node replica  \
# 0   /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 2   /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 3   /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 6   /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 11  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 13  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 14  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 15  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 16  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 17  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 18  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 21  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 23  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 24  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 25  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 26  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 28  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 30  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 31  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 35  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 39  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 40  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 42  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 43  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 44  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 46  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 47  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 49  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 50  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 51  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 52  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
#
#      time_create
# 0   1.475142e+09
# 2   1.475144e+09
# 3   1.475146e+09
# 6   1.475165e+09
# 11  1.475169e+09
# 13  1.475189e+09
# 14  1.475166e+09
# 15  1.475162e+09
# 16  1.475161e+09
# 17  1.475147e+09
# 18  1.475183e+09
# 21  1.475172e+09
# 23  1.475188e+09
# 24  1.475174e+09
# 25  1.475178e+09
# 26  1.475159e+09
# 28  1.475191e+09
# 30  1.475175e+09
# 31  1.475167e+09
# 35  1.475186e+09
# 39  1.475185e+09
# 40  1.475172e+09
# 42  1.475179e+09
# 43  1.475173e+09
# 44  1.475189e+09
# 46  1.475165e+09
# 47  1.475156e+09
# 49  1.475155e+09
# 50  1.475141e+09
# 51  1.475164e+09
# 52  1.475188e+09
# Number of non-source files: 31 of 55

# %%
def site_nosource_files_df(site):
    '''
    check the data service blockarrive for blocks with status basis = -6
    basis -6 means: at least one file in the block has no source replica remaining
    It returns a dictionary with a dataframe containing the metainformation of with files with no source of all blocks and
    a dataframe with the metainfomation at the block level of all theh blocks with -6 statue for the evaluated site
    '''
    #Get the info of blockarrive for the site parsed in a panda dataframe
    # panda dataframe with the info at block level: blocks_arrive_table
    url = "https://cmsweb.cern.ch/phedex/datasvc/json/prod/blockarrive"
    params = {"to_node": site,"basis": -6}
    block_arrive_info = requests.get(url=url, params= params, verify=False).content

    block_arrive_info_json = json.loads(block_arrive_info)
    blocks_arrive_table = json_normalize(block_arrive_info_json['phedex']['block'])


    #Get the info for non-source files and how many of all the files in the block have non-source
    #nosource_files_df: have the information of the non-source file. At file level
    # blocks_info_df: have the information at block level that block_arrive table has and additionally the count of ns files
    ns_files_list = []
    blocks_info_df = pd.DataFrame()
    for blockname in blocks_arrive_table['name']:
        nosource_files_info = get_nosource_files_info(blockname)
        nosource_files_df = nosource_files_info['df']
        nosource_files_df['blockname'] = blockname
        ns_files_list.append(nosource_files_df)
        df_tmp = pd.DataFrame(data= [[nosource_files_info['num_files_in_block'], nosource_files_info['num_nosource_files_in_block']]])
        blocks_info_df = blocks_info_df.append(df_tmp, ignore_index=True)

    nosource_files_df =  pd.concat(ns_files_list)
    nosource_files_df['datetime_create'] = nosource_files_df['time_create'].apply(datetime.fromtimestamp)
    nosource_files_df['dataset'] = nosource_files_df['blockname'].apply(dataset_from_blockname)

    blocks_info_df.columns = ['num_files_in_block', 'num_nosource_files_in_block']
    blocks_info_df = pd.concat([blocks_arrive_table,blocks_info_df], axis=1)

    return {'files_info': nosource_files_df, 'blocks_info': blocks_info_df}

# %% [markdown]
# ### Example of site_nosource_files_df( site, basis )

# %%
site = "T1_US_FNAL_MSS"

nosource_site_info = site_nosource_files_df(site)
display(nosource_site_info['files_info'])
display(nosource_site_info['blocks_info'])
# Out:
#          bytes                           checksum         id  \
# 0   4752817175  adler32:c4e9fd9f,cksum:3982282292   83491612
# 0   2713083854  adler32:a2f170e3,cksum:1986985331  104541926
# 1   4006024947    adler32:51435245,cksum:24716296  104543345
# 2   2520895924  adler32:6f16d7bd,cksum:3956406453  104541982
# 3   3596321947  adler32:9821dd1f,cksum:1277982894  104542900
# 4   3157685787  adler32:480a0164,cksum:3216692587  104543485
# 5   2832391222  adler32:7078d070,cksum:2613710556  104541686
# 6   4031842227  adler32:ac5cd63f,cksum:3697835106  104542898
# 7   4025257470   adler32:821b88c0,cksum:216284042  104544341
# 8   4031585377  adler32:c45a11bd,cksum:1953835665  104544573
# 9   3998607627  adler32:5a3f7977,cksum:3898730313  104544013
# 10  3998001291  adler32:a8ca357a,cksum:2686640609  104544821
# 11  4032337999  adler32:10e206a0,cksum:1879614170  104545208
# 12  4031234892  adler32:a17b159b,cksum:3801942712  104544011
# 13  2458646373  adler32:6b77a633,cksum:2094442423  104542227
# 14  2094034974  adler32:cc6b8d21,cksum:3932313819  104541566
# 15  4030454351   adler32:db8d7b5b,cksum:138082241  104542882
# 16  3033423968  adler32:2547843d,cksum:2201795804  104541928
# 17  4022685500   adler32:1966dc1b,cksum:930854419  104546175
# 18  4032345532   adler32:b51a3d18,cksum:952684748  104542811
# 19  4023032831  adler32:0a2bdc73,cksum:3151108653  104546507
# 20  4043472926  adler32:27c41f94,cksum:2883014015  104545212
# 21  4036358500  adler32:04a3d9cf,cksum:1512987979  104544450
# 22  4029832928  adler32:fd92f29b,cksum:3257125835  104545210
# 23  4026089074  adler32:86bfa1b5,cksum:1653407552  104543490
# 24  4039107659  adler32:1e559579,cksum:3423587027  104544818
# 25  4018584660  adler32:9cdffdcd,cksum:3993235455  104544338
# 26  4001984916  adler32:d135a79a,cksum:3552840364  104545845
# 27  2978592816  adler32:53495359,cksum:2183226032  104541885
# 28  4042170686  adler32:e3851d72,cksum:2508499612  104542011
# ..         ...                                ...        ...
# 2   2446225392  adler32:637d2e73,cksum:3564716832  101460134
# 3   2492112257  adler32:52ce435c,cksum:2214022121  101463210
# 6   2387554713  adler32:28874f74,cksum:1531599078  101482960
# 11  2322897779  adler32:5cc6c949,cksum:1101638021  101487218
# 13  3397572478  adler32:3d945dc3,cksum:4160566198  101511084
# 14  2359316290   adler32:da333a33,cksum:522016462  101483764
# 15  2381648457  adler32:d2053c21,cksum:1710051829  101479006
# 16  2383272277  adler32:8bc8cfc7,cksum:2568201960  101478547
# 17  2428671269  adler32:c02906d2,cksum:3865174811  101464007
# 18  2284817253  adler32:70760b0a,cksum:3620367416  101503289
# 21  2348248012  adler32:ca8bd11d,cksum:1013251246  101490245
# 23  2561919683  adler32:0a952185,cksum:3710306270  101510333
# 24  2360996621   adler32:8df61486,cksum:397336793  101492674
# 25  2242282930  adler32:b1916896,cksum:1322389979  101496415
# 26  2411078493  adler32:5e10ade7,cksum:1043591874  101475141
# 28  2519191679   adler32:e835d8ce,cksum:869109351  101513545
# 30  2337340518  adler32:66ac705f,cksum:2364421772  101493587
# 31  2346435413   adler32:bda26c8e,cksum:814785190  101485808
# 35  2284485682  adler32:0994ff8d,cksum:1853346002  101507464
# 39  2289788578  adler32:335a90b9,cksum:1958765787  101506238
# 40  2324108968  adler32:067dd98b,cksum:1168199932  101489251
# 42  2229046282   adler32:54b13f72,cksum:123517567  101497448
# 43  3505222995   adler32:7f06f8ea,cksum:712941224  101492054
# 44  2514467037  adler32:caf974e1,cksum:3992066838  101510841
# 46  2439297959  adler32:4d196d8b,cksum:3783968185  101482925
# 47  2411966479  adler32:45c7e841,cksum:2327251435  101472604
# 49  2454100010   adler32:6c289104,cksum:619024169  101471094
# 50  2330195082   adler32:10aca824,cksum:680891312  101457012
# 51  2437390592  adler32:a7543b91,cksum:4057095438  101481575
# 52  2273343719  adler32:d3004ad5,cksum:3685305564  101510549
#
#                                                  name original_node replica  \
# 0   /store/data/Run2015D/SingleMuon/RECO/16Dec2015...          None      []
# 0   /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 1   /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 2   /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 3   /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 4   /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 5   /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 6   /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 7   /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 8   /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 9   /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 10  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 11  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 12  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 13  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 14  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 15  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 16  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 17  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 18  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 19  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 20  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 21  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 22  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 23  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 24  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 25  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 26  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 27  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 28  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# ..                                                ...           ...     ...
# 2   /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 3   /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 6   /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 11  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 13  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 14  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 15  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 16  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 17  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 18  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 21  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 23  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 24  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 25  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 26  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 28  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 30  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 31  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 35  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 39  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 40  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 42  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 43  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 44  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 46  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 47  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 49  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 50  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 51  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 52  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
#
#      time_create                                          blockname  \
# 0   1.450709e+09  /SingleMuon/Run2015D-16Dec2015-v1/RECO#4252054...
# 0   1.478732e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 1   1.478734e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 2   1.478733e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 3   1.478734e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 4   1.478735e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 5   1.478732e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 6   1.478734e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 7   1.478736e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 8   1.478737e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 9   1.478735e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 10  1.478737e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 11  1.478738e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 12  1.478735e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 13  1.478733e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 14  1.478732e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 15  1.478734e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 16  1.478732e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 17  1.478739e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 18  1.478734e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 19  1.478740e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 20  1.478738e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 21  1.478736e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 22  1.478738e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 23  1.478735e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 24  1.478737e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 25  1.478736e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 26  1.478739e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 27  1.478732e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 28  1.478733e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# ..           ...                                                ...
# 2   1.475144e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 3   1.475146e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 6   1.475165e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 11  1.475169e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 13  1.475189e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 14  1.475166e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 15  1.475162e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 16  1.475161e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 17  1.475147e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 18  1.475183e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 21  1.475172e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 23  1.475188e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 24  1.475174e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 25  1.475178e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 26  1.475159e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 28  1.475191e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 30  1.475175e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 31  1.475167e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 35  1.475186e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 39  1.475185e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 40  1.475172e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 42  1.475179e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 43  1.475173e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 44  1.475189e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 46  1.475165e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 47  1.475156e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 49  1.475155e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 50  1.475141e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 51  1.475164e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 52  1.475188e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
#
#               datetime_create  \
# 0  2015-12-21 08:36:49.513020
# 0  2016-11-09 17:00:15.302690
# 1  2016-11-09 17:32:53.108160
# 2  2016-11-09 17:03:36.459760
# 3  2016-11-09 17:23:44.365570
# 4  2016-11-09 17:36:14.130630
# 5  2016-11-09 16:48:31.042490
# 6  2016-11-09 17:23:44.365570
# 7  2016-11-09 17:59:47.331060
# 8  2016-11-09 18:09:51.426270
# 9  2016-11-09 17:48:01.031730
# 10 2016-11-09 18:18:13.927170
# 11 2016-11-09 18:33:17.472110
# 12 2016-11-09 17:48:01.031730
# 13 2016-11-09 17:15:20.998180
# 14 2016-11-09 16:45:09.772500
# 15 2016-11-09 17:22:03.412510
# 16 2016-11-09 17:00:15.302690
# 17 2016-11-09 18:48:22.147660
# 18 2016-11-09 17:18:42.227370
# 19 2016-11-09 19:03:27.133670
# 20 2016-11-09 18:33:17.472110
# 21 2016-11-09 18:06:30.308840
# 22 2016-11-09 18:33:17.472110
# 23 2016-11-09 17:36:14.130630
# 24 2016-11-09 18:18:13.927170
# 25 2016-11-09 17:59:47.331060
# 26 2016-11-09 18:45:00.865890
# 27 2016-11-09 16:56:53.893180
# 28 2016-11-09 17:05:17.466740
# ..                        ...
# 2  2016-09-29 05:05:05.038910
# 3  2016-09-29 05:50:08.023270
# 6  2016-09-29 10:58:51.905130
# 11 2016-09-29 12:07:18.126790
# 13 2016-09-29 17:42:48.628780
# 14 2016-09-29 11:17:13.372240
# 15 2016-09-29 10:08:47.017680
# 16 2016-09-29 10:00:26.302010
# 17 2016-09-29 06:08:29.630190
# 18 2016-09-29 16:10:58.933180
# 21 2016-09-29 13:05:43.064490
# 23 2016-09-29 17:27:45.908590
# 24 2016-09-29 13:37:26.072690
# 25 2016-09-29 14:40:51.351770
# 26 2016-09-29 09:18:43.308120
# 28 2016-09-29 18:09:30.466770
# 30 2016-09-29 13:54:07.577880
# 31 2016-09-29 11:43:56.012800
# 35 2016-09-29 16:57:43.536760
# 39 2016-09-29 16:37:41.603630
# 40 2016-09-29 12:52:21.622700
# 42 2016-09-29 14:57:32.745970
# 43 2016-09-29 13:22:24.749260
# 44 2016-09-29 17:37:47.578810
# 46 2016-09-29 10:57:11.508900
# 47 2016-09-29 08:33:39.838400
# 49 2016-09-29 08:15:18.537670
# 50 2016-09-29 04:16:39.115430
# 51 2016-09-29 10:45:30.448200
# 52 2016-09-29 17:34:26.990770
#
#                                               dataset
# 0              /SingleMuon/Run2015D-16Dec2015-v1/RECO
# 0   /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 1   /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 2   /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 3   /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 4   /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 5   /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 6   /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 7   /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 8   /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 9   /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 10  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 11  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 12  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 13  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 14  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 15  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 16  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 17  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 18  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 19  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 20  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 21  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 22  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 23  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 24  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 25  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 26  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 27  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 28  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# ..                                                ...
# 2          /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 3          /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 6          /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 11         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 13         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 14         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 15         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 16         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 17         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 18         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 21         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 23         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 24         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 25         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 26         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 28         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 30         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 31         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 35         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 39         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 40         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 42         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 43         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 44         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 46         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 47         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 49         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 50         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 51         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 52         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
#
# [274 rows x 10 columns]
#           bytes                                            dataset  \
# 0    4752817175             /SingleMuon/Run2015D-16Dec2015-v1/RECO
# 1  512873882415  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 2     126221101                                  /BTag/None-v0/AOD
# 3    4553925469  /SingleNeutrino/RunIISummer16DR80-PUFlat0to50_...
# 4   14175442011  /SingleNeutrino/RunIISummer16DR80-PUFlat0to50_...
# 5  101697018661  /SingleNeutrino/RunIISummer16DR80-PUFlat0to50_...
# 6    7707307007  /MuGunFlatPt2to8/TTI2023Upg14D-FLATBS15PU200_F...
# 7  172183097185  /QCD_Pt-15to7000_TuneCUETHS1_FlatP6_13TeV_herw...
# 8    3642742308     /BTagCSV/Run2016BBackfill-BACKFILL-v13/MINIAOD
# 9  138057876940         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
#
#                                          destination  files       id  \
# 0  [{u'files': 1, u'name': u'T1_US_FNAL_Disk', u'...      1  5912292
# 1  [{u'files': 135, u'name': u'T1_US_FNAL_Disk', ...    135  7794552
# 2  [{u'files': 1, u'name': u'T1_US_FNAL_Disk', u'...      1  4574137
# 3  [{u'files': 2, u'name': u'T1_US_FNAL_Disk', u'...      2  7874253
# 4  [{u'files': 6, u'name': u'T1_US_FNAL_Disk', u'...      6  7870112
# 5  [{u'files': 32, u'name': u'T1_US_FNAL_Disk', u...     32  7869576
# 6  [{u'files': 4, u'name': u'T1_US_FNAL_Disk', u'...      4  7836394
# 7  [{u'files': 63, u'name': u'T1_US_FNAL_Disk', u...     63  7871689
# 8  [{u'files': 3, u'name': u'T1_US_FNAL_Disk', u'...      3  7580925
# 9  [{u'files': 55, u'name': u'T1_US_FNAL_Disk', u...     55  7582879
#
#                                                 name   time_create  \
# 0  /SingleMuon/Run2015D-16Dec2015-v1/RECO#4252054...  1.450708e+09
# 1  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...  1.478731e+09
# 2  /BTag/None-v0/AOD#a95a28d0-1134-11e4-81d1-0022...  1.405988e+09
# 3  /SingleNeutrino/RunIISummer16DR80-PUFlat0to50_...  1.480413e+09
# 4  /SingleNeutrino/RunIISummer16DR80-PUFlat0to50_...  1.480333e+09
# 5  /SingleNeutrino/RunIISummer16DR80-PUFlat0to50_...  1.480320e+09
# 6  /MuGunFlatPt2to8/TTI2023Upg14D-FLATBS15PU200_F...  1.479598e+09
# 7  /QCD_Pt-15to7000_TuneCUETHS1_FlatP6_13TeV_herw...  1.480362e+09
# 8  /BTagCSV/Run2016BBackfill-BACKFILL-v13/MINIAOD...  1.475114e+09
# 9  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...  1.475141e+09
#
#     time_update  num_files_in_block  num_nosource_files_in_block
# 0  1.476532e+09                   1                            1
# 1  1.478797e+09                 135                          135
# 2  1.406054e+09                   1                            1
# 3  1.480428e+09                   2                            2
# 4  1.480427e+09                   6                            6
# 5  1.480427e+09                  32                           32
# 6  1.496276e+09                   4                            1
# 7  1.480416e+09                  63                           63
# 8  1.475180e+09                   3                            2
# 9  1.475207e+09                  55                           31

# %% [markdown]
# ## Procedure for one site

# %%
#For one site

site =  "T1_US_FNAL_Disk"
nosource_site_info = site_nosource_files_df(site)

#file level df
ns_files_info = nosource_site_info['files_info']
#block level df
ns_blocks_info = nosource_site_info['blocks_info']

#Sum of the size reported for all the files with no source found
#This with to help to compare with the plot of idle data for the site for with the subscriptions has been investigated
ns_files_size = ns_files_info['bytes'].sum() 
ns_files_size_TB = ns_files_size * (10**(-12))
#Num of files
num_ns_files = len(ns_files_info)
    
print 'For blocks subscriptions to {}, {} files where found to have no source.'.format(site, num_ns_files)
print 'Total size: {} TB'.format(ns_files_size_TB)
# Out:
# For blocks subscriptions to T1_US_FNAL_Disk, 274 files where found to have no source.
# Total size: 0.891015672335 TB

# %%
ns_files_info
# Out:
#          bytes                           checksum         id  \
# 0   4752817175  adler32:c4e9fd9f,cksum:3982282292   83491612
# 0   2713083854  adler32:a2f170e3,cksum:1986985331  104541926
# 1   4006024947    adler32:51435245,cksum:24716296  104543345
# 2   2520895924  adler32:6f16d7bd,cksum:3956406453  104541982
# 3   3596321947  adler32:9821dd1f,cksum:1277982894  104542900
# 4   3157685787  adler32:480a0164,cksum:3216692587  104543485
# 5   2832391222  adler32:7078d070,cksum:2613710556  104541686
# 6   4031842227  adler32:ac5cd63f,cksum:3697835106  104542898
# 7   4025257470   adler32:821b88c0,cksum:216284042  104544341
# 8   4031585377  adler32:c45a11bd,cksum:1953835665  104544573
# 9   3998607627  adler32:5a3f7977,cksum:3898730313  104544013
# 10  3998001291  adler32:a8ca357a,cksum:2686640609  104544821
# 11  4032337999  adler32:10e206a0,cksum:1879614170  104545208
# 12  4031234892  adler32:a17b159b,cksum:3801942712  104544011
# 13  2458646373  adler32:6b77a633,cksum:2094442423  104542227
# 14  2094034974  adler32:cc6b8d21,cksum:3932313819  104541566
# 15  4030454351   adler32:db8d7b5b,cksum:138082241  104542882
# 16  3033423968  adler32:2547843d,cksum:2201795804  104541928
# 17  4022685500   adler32:1966dc1b,cksum:930854419  104546175
# 18  4032345532   adler32:b51a3d18,cksum:952684748  104542811
# 19  4023032831  adler32:0a2bdc73,cksum:3151108653  104546507
# 20  4043472926  adler32:27c41f94,cksum:2883014015  104545212
# 21  4036358500  adler32:04a3d9cf,cksum:1512987979  104544450
# 22  4029832928  adler32:fd92f29b,cksum:3257125835  104545210
# 23  4026089074  adler32:86bfa1b5,cksum:1653407552  104543490
# 24  4039107659  adler32:1e559579,cksum:3423587027  104544818
# 25  4018584660  adler32:9cdffdcd,cksum:3993235455  104544338
# 26  4001984916  adler32:d135a79a,cksum:3552840364  104545845
# 27  2978592816  adler32:53495359,cksum:2183226032  104541885
# 28  4042170686  adler32:e3851d72,cksum:2508499612  104542011
# ..         ...                                ...        ...
# 2   2446225392  adler32:637d2e73,cksum:3564716832  101460134
# 3   2492112257  adler32:52ce435c,cksum:2214022121  101463210
# 6   2387554713  adler32:28874f74,cksum:1531599078  101482960
# 11  2322897779  adler32:5cc6c949,cksum:1101638021  101487218
# 13  3397572478  adler32:3d945dc3,cksum:4160566198  101511084
# 14  2359316290   adler32:da333a33,cksum:522016462  101483764
# 15  2381648457  adler32:d2053c21,cksum:1710051829  101479006
# 16  2383272277  adler32:8bc8cfc7,cksum:2568201960  101478547
# 17  2428671269  adler32:c02906d2,cksum:3865174811  101464007
# 18  2284817253  adler32:70760b0a,cksum:3620367416  101503289
# 21  2348248012  adler32:ca8bd11d,cksum:1013251246  101490245
# 23  2561919683  adler32:0a952185,cksum:3710306270  101510333
# 24  2360996621   adler32:8df61486,cksum:397336793  101492674
# 25  2242282930  adler32:b1916896,cksum:1322389979  101496415
# 26  2411078493  adler32:5e10ade7,cksum:1043591874  101475141
# 28  2519191679   adler32:e835d8ce,cksum:869109351  101513545
# 30  2337340518  adler32:66ac705f,cksum:2364421772  101493587
# 31  2346435413   adler32:bda26c8e,cksum:814785190  101485808
# 35  2284485682  adler32:0994ff8d,cksum:1853346002  101507464
# 39  2289788578  adler32:335a90b9,cksum:1958765787  101506238
# 40  2324108968  adler32:067dd98b,cksum:1168199932  101489251
# 42  2229046282   adler32:54b13f72,cksum:123517567  101497448
# 43  3505222995   adler32:7f06f8ea,cksum:712941224  101492054
# 44  2514467037  adler32:caf974e1,cksum:3992066838  101510841
# 46  2439297959  adler32:4d196d8b,cksum:3783968185  101482925
# 47  2411966479  adler32:45c7e841,cksum:2327251435  101472604
# 49  2454100010   adler32:6c289104,cksum:619024169  101471094
# 50  2330195082   adler32:10aca824,cksum:680891312  101457012
# 51  2437390592  adler32:a7543b91,cksum:4057095438  101481575
# 52  2273343719  adler32:d3004ad5,cksum:3685305564  101510549
#
#                                                  name original_node replica  \
# 0   /store/data/Run2015D/SingleMuon/RECO/16Dec2015...          None      []
# 0   /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 1   /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 2   /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 3   /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 4   /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 5   /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 6   /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 7   /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 8   /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 9   /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 10  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 11  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 12  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 13  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 14  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 15  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 16  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 17  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 18  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 19  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 20  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 21  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 22  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 23  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 24  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 25  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 26  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 27  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# 28  /store/mc/RunIISummer16DR80Premix/DYJetsToNuNu...          None      []
# ..                                                ...           ...     ...
# 2   /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 3   /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 6   /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 11  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 13  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 14  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 15  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 16  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 17  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 18  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 21  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 23  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 24  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 25  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 26  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 28  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 30  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 31  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 35  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 39  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 40  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 42  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 43  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 44  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 46  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 47  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 49  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 50  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 51  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
# 52  /store/data/Run2016BBackfill/BTagCSV/AOD/BACKF...          None      []
#
#      time_create                                          blockname  \
# 0   1.450709e+09  /SingleMuon/Run2015D-16Dec2015-v1/RECO#4252054...
# 0   1.478732e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 1   1.478734e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 2   1.478733e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 3   1.478734e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 4   1.478735e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 5   1.478732e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 6   1.478734e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 7   1.478736e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 8   1.478737e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 9   1.478735e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 10  1.478737e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 11  1.478738e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 12  1.478735e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 13  1.478733e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 14  1.478732e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 15  1.478734e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 16  1.478732e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 17  1.478739e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 18  1.478734e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 19  1.478740e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 20  1.478738e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 21  1.478736e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 22  1.478738e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 23  1.478735e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 24  1.478737e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 25  1.478736e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 26  1.478739e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 27  1.478732e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 28  1.478733e+09  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# ..           ...                                                ...
# 2   1.475144e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 3   1.475146e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 6   1.475165e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 11  1.475169e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 13  1.475189e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 14  1.475166e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 15  1.475162e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 16  1.475161e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 17  1.475147e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 18  1.475183e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 21  1.475172e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 23  1.475188e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 24  1.475174e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 25  1.475178e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 26  1.475159e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 28  1.475191e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 30  1.475175e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 31  1.475167e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 35  1.475186e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 39  1.475185e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 40  1.475172e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 42  1.475179e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 43  1.475173e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 44  1.475189e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 46  1.475165e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 47  1.475156e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 49  1.475155e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 50  1.475141e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 51  1.475164e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
# 52  1.475188e+09  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c9...
#
#               datetime_create  \
# 0  2015-12-21 08:36:49.513020
# 0  2016-11-09 17:00:15.302690
# 1  2016-11-09 17:32:53.108160
# 2  2016-11-09 17:03:36.459760
# 3  2016-11-09 17:23:44.365570
# 4  2016-11-09 17:36:14.130630
# 5  2016-11-09 16:48:31.042490
# 6  2016-11-09 17:23:44.365570
# 7  2016-11-09 17:59:47.331060
# 8  2016-11-09 18:09:51.426270
# 9  2016-11-09 17:48:01.031730
# 10 2016-11-09 18:18:13.927170
# 11 2016-11-09 18:33:17.472110
# 12 2016-11-09 17:48:01.031730
# 13 2016-11-09 17:15:20.998180
# 14 2016-11-09 16:45:09.772500
# 15 2016-11-09 17:22:03.412510
# 16 2016-11-09 17:00:15.302690
# 17 2016-11-09 18:48:22.147660
# 18 2016-11-09 17:18:42.227370
# 19 2016-11-09 19:03:27.133670
# 20 2016-11-09 18:33:17.472110
# 21 2016-11-09 18:06:30.308840
# 22 2016-11-09 18:33:17.472110
# 23 2016-11-09 17:36:14.130630
# 24 2016-11-09 18:18:13.927170
# 25 2016-11-09 17:59:47.331060
# 26 2016-11-09 18:45:00.865890
# 27 2016-11-09 16:56:53.893180
# 28 2016-11-09 17:05:17.466740
# ..                        ...
# 2  2016-09-29 05:05:05.038910
# 3  2016-09-29 05:50:08.023270
# 6  2016-09-29 10:58:51.905130
# 11 2016-09-29 12:07:18.126790
# 13 2016-09-29 17:42:48.628780
# 14 2016-09-29 11:17:13.372240
# 15 2016-09-29 10:08:47.017680
# 16 2016-09-29 10:00:26.302010
# 17 2016-09-29 06:08:29.630190
# 18 2016-09-29 16:10:58.933180
# 21 2016-09-29 13:05:43.064490
# 23 2016-09-29 17:27:45.908590
# 24 2016-09-29 13:37:26.072690
# 25 2016-09-29 14:40:51.351770
# 26 2016-09-29 09:18:43.308120
# 28 2016-09-29 18:09:30.466770
# 30 2016-09-29 13:54:07.577880
# 31 2016-09-29 11:43:56.012800
# 35 2016-09-29 16:57:43.536760
# 39 2016-09-29 16:37:41.603630
# 40 2016-09-29 12:52:21.622700
# 42 2016-09-29 14:57:32.745970
# 43 2016-09-29 13:22:24.749260
# 44 2016-09-29 17:37:47.578810
# 46 2016-09-29 10:57:11.508900
# 47 2016-09-29 08:33:39.838400
# 49 2016-09-29 08:15:18.537670
# 50 2016-09-29 04:16:39.115430
# 51 2016-09-29 10:45:30.448200
# 52 2016-09-29 17:34:26.990770
#
#                                               dataset
# 0              /SingleMuon/Run2015D-16Dec2015-v1/RECO
# 0   /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 1   /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 2   /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 3   /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 4   /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 5   /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 6   /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 7   /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 8   /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 9   /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 10  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 11  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 12  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 13  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 14  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 15  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 16  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 17  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 18  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 19  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 20  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 21  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 22  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 23  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 24  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 25  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 26  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 27  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# 28  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-...
# ..                                                ...
# 2          /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 3          /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 6          /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 11         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 13         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 14         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 15         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 16         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 17         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 18         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 21         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 23         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 24         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 25         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 26         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 28         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 30         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 31         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 35         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 39         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 40         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 42         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 43         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 44         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 46         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 47         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 49         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 50         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 51         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# 52         /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
#
# [274 rows x 10 columns]

# %%
def count_file_type (ns_files_df):
    '''
    From a non-source files dataframe get the number of files that
    are 'data', 'mc' or 'other' types.
    '''
    count_file_type = {}
    for filepath in ns_files_info['name']:
        if re.search('^/store/data', filepath):
            count_file_type['data'] =  count_file_type.get('data', 0) + 1
        elif re.search('^/store/mc', filepath):
            count_file_type['mc'] =  count_file_type.get('mc', 0) + 1
        else:
            count_file_type['others'] =  count_file_type.get('others', 0) + 1
    return count_file_type

# %%
#Files types diversity 
count_file_type_dic = count_file_type(ns_files_info)

for file_type, count in count_file_type_dic.iteritems():
    print str(count) + " " + file_type + " at " + site
# Out:
# 35 data at T1_US_FNAL_Disk
# 239 mc at T1_US_FNAL_Disk

# %%
def datasets_count_hash(blocks_file_list):
    '''
    From a list of the blocks identified with basis -6
    Produces a dictionary listing the involve datasets as keys and the num of blocks (with basis -6) as values
     '''
    datasets_count = {}
    for i in blocks_file_list:
        dataset = dataset_from_blockname(str(i))
        datasets_count[dataset] = datasets_count.get(dataset, 0) + 1
    return datasets_count

# %%
#Datasets and corresponding number of blocks involve (basis -6)
datasets_count = datasets_count_hash(ns_blocks_info['name'].tolist())
datasets_count
# Out:
# {'/BTag/None-v0/AOD': 1,
#  '/BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD': 1,
#  '/BTagCSV/Run2016BBackfill-BACKFILL-v13/MINIAOD': 1,
#  '/DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8/RunIISummer16DR80Premix-PUMoriond17_80X_mcRun2_asymptotic_2016_TrancheIV_v6-v1/AODSIM': 1,
#  '/MuGunFlatPt2to8/TTI2023Upg14D-FLATBS15PU200_FLATBS15_DES23_62_V1-v3/GEN-SIM-DIGI-RAW': 1,
#  '/QCD_Pt-15to7000_TuneCUETHS1_FlatP6_13TeV_herwigpp/RunIISummer16DR80-PUFlat0to50_80X_mcRun2_asymptotic_2016_TrancheIV_v6-v1/AODSIM': 1,
#  '/SingleMuon/Run2015D-16Dec2015-v1/RECO': 1,
#  '/SingleNeutrino/RunIISummer16DR80-PUFlat0to50_magnetOff_80X_mcRun2_asymptotic_2016_TrancheIV_v6-v3/AODSIM': 3}

# %%
def counts_for_dataset(dataset):
    '''
    For a dataset, retrieves relevant summary information, i.e.,
    returns total number of files and total number of blocks
    '''
    url = 'https://cmsweb.cern.ch/phedex/datasvc/json/prod/data'
    params = {"dataset": dataset, "level": 'block'}
    data_info = requests.get(url=url, params= params, verify=False).content
    data_json = json.loads(data_info)
    data_table = json_normalize(data_json['phedex']['dbs'][0]['dataset'][0]['block'])
    return {'num_files': data_table['files'].sum(), 'num_blocks': len(data_table)}

# %%
#Get total number of files and total number of blocks
datasets_total = {}
for dataset in datasets_count:
    datasets_total[dataset] = counts_for_dataset(dataset)

# %%
datasets_total
# Out:
# {'/BTag/None-v0/AOD': {'num_blocks': 4, 'num_files': 20},
#  '/BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD': {'num_blocks': 22,
#   'num_files': 565},
#  '/BTagCSV/Run2016BBackfill-BACKFILL-v13/MINIAOD': {'num_blocks': 16,
#   'num_files': 159},
#  '/DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8/RunIISummer16DR80Premix-PUMoriond17_80X_mcRun2_asymptotic_2016_TrancheIV_v6-v1/AODSIM': {'num_blocks': 21,
#   'num_files': 2217},
#  '/MuGunFlatPt2to8/TTI2023Upg14D-FLATBS15PU200_FLATBS15_DES23_62_V1-v3/GEN-SIM-DIGI-RAW': {'num_blocks': 1,
#   'num_files': 4},
#  '/QCD_Pt-15to7000_TuneCUETHS1_FlatP6_13TeV_herwigpp/RunIISummer16DR80-PUFlat0to50_80X_mcRun2_asymptotic_2016_TrancheIV_v6-v1/AODSIM': {'num_blocks': 1,
#   'num_files': 63},
#  '/SingleMuon/Run2015D-16Dec2015-v1/RECO': {'num_blocks': 81,
#   'num_files': 7818},
#  '/SingleNeutrino/RunIISummer16DR80-PUFlat0to50_magnetOff_80X_mcRun2_asymptotic_2016_TrancheIV_v6-v3/AODSIM': {'num_blocks': 9,
#   'num_files': 214}}

# %%
def dataset_kind_is(dataset):
    '''
    From dataset name returns the type of file it contains: 'data',  'mc'....
    '''
    url = 'https://cmsweb.cern.ch/phedex/datasvc/json/prod/filereplicas'
    params = {"dataset": dataset}
    replicas_info = requests.get(url=url, params= params, verify=False).content
    replicas_json = json.loads(replicas_info)
    replicas_sample_table = json_normalize(replicas_json['phedex']['block'][0]['file'])
    return (str(replicas_sample_table['name'][0]).split("/")[2])

# %%
for i in datasets_total:
    print dataset_kind_is(i)
# Out:
# mc
# data
# mc
# mc
# data
# data
# data
# mc

# %%
def check_filetype (filepath, file_type):
    '''
    check if a file is of a specific category: 'mc',  'data' and 'other'
    '''
    return bool(re.search('^/store/' + file_type, filepath))

# %%
def write_nosource_files_site (site, file_type, list_files):
    filename = "nosource_files_" + file_type + "_" + site + ".txt"

    with open(filename, "w") as f:
        f.write("\n".join(list_files))

def write_nosource_block_list (site, file_type, list_blocks):
    filename = "nosource_blocks_" + file_type + "_" + site + ".txt"

    with open(filename, "w") as f:
        f.write("\n".join(list_blocks))

def write_nosource_dataset_list (site, file_type, list_datasets):
    filename = "nosource_datasets_" + file_type + "_" + site + ".txt"

# %%
for file_type in count_file_type_dic.keys():
    print ('Type of files: ' + file_type)
    whole_blocks_ns = []
    whole_datasets_ns = []
    for dataset in datasets_count:
        if (dataset_kind_is(dataset) == file_type):
            n_files = datasets_total[dataset]['num_files']
            ns_blocks_info_subset = ns_blocks_info[ns_blocks_info.dataset == dataset]
            num_ns_files = ns_blocks_info_subset.num_nosource_files_in_block.sum()
            num_ns_blocks = datasets_count[dataset]
            num_tot_blocks = datasets_total[dataset]['num_blocks']
            print 'Dataset: {}'.format(dataset)
            print 'Num of blocks with no source files: {}/{}'.format(num_ns_blocks, num_tot_blocks)
            print 'Num of no source files: {}/{}'.format(num_ns_files, n_files)
            print 'Num of no source files by block:'
            if (num_ns_blocks == num_tot_blocks and num_ns_files == n_files):
                whole_datasets_ns.append(dataset)

            for idx, row in ns_blocks_info_subset.iterrows():
                print ' {} {}/{}'.format(row['name'], row.num_nosource_files_in_block, row.num_files_in_block)
                if (row.num_nosource_files_in_block == row.num_files_in_block and (num_ns_blocks !=num_tot_blocks and num_ns_files != n_files)):
                    whole_blocks_ns.append(row['name'])
            print '=' * 100
    list_whole_ns_files = ns_files_info[ns_files_info.name.apply(check_filetype, file_type = file_type)]['name'].tolist()
    nosource_files_site_df = ns_files_info[~ns_files_info.dataset.isin(whole_datasets_ns) & ~ns_files_info.blockname.isin(whole_blocks_ns)]
    list_ns_files = ns_files_info['name'].tolist()
    list_ns_files = [ ns_file for ns_file in list_ns_files if re.search('^/store/' + file_type, ns_file)]
    
    '''
    print '=' * 100
    print '=' * 100
    print list_whole_ns_files
    print '=' * 100
    print whole_blocks_ns
    print '=' * 100
    print whole_datasets_ns
    print '=' * 100
    list_ns_files
    '''

    write_nosource_block_list(site, file_type, whole_blocks_ns)
    write_nosource_dataset_list(site, file_type, whole_datasets_ns)
    write_nosource_files_site(site, file_type, list_ns_files)
    write_nosource_files_site(site, file_type + '_whole', list_whole_ns_files)
# Out:
# Type of files: data
# Dataset: /SingleMuon/Run2015D-16Dec2015-v1/RECO
# Num of blocks with no source files: 1/81
# Num of no source files: 1/7818
# Num of no source files by block:
#  /SingleMuon/Run2015D-16Dec2015-v1/RECO#42520542-a7ef-11e5-b857-a0369f23cf8a 1/1
# ====================================================================================================
# Dataset: /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD
# Num of blocks with no source files: 1/22
# Num of no source files: 31/565
# Num of no source files by block:
#  /BTagCSV/Run2016BBackfill-BACKFILL-v13/AOD#6c960820-8625-11e6-b16f-02163e0184a6 31/55
# ====================================================================================================
# Dataset: /BTag/None-v0/AOD
# Num of blocks with no source files: 1/4
# Num of no source files: 1/20
# Num of no source files by block:
#  /BTag/None-v0/AOD#a95a28d0-1134-11e4-81d1-00221959e777 1/1
# ====================================================================================================
# Dataset: /BTagCSV/Run2016BBackfill-BACKFILL-v13/MINIAOD
# Num of blocks with no source files: 1/16
# Num of no source files: 2/159
# Num of no source files by block:
#  /BTagCSV/Run2016BBackfill-BACKFILL-v13/MINIAOD#3d3fd31e-85e7-11e6-b16f-02163e0184a6 2/3
# ====================================================================================================
# Type of files: mc
# Dataset: /QCD_Pt-15to7000_TuneCUETHS1_FlatP6_13TeV_herwigpp/RunIISummer16DR80-PUFlat0to50_80X_mcRun2_asymptotic_2016_TrancheIV_v6-v1/AODSIM
# Num of blocks with no source files: 1/1
# Num of no source files: 63/63
# Num of no source files by block:
#  /QCD_Pt-15to7000_TuneCUETHS1_FlatP6_13TeV_herwigpp/RunIISummer16DR80-PUFlat0to50_80X_mcRun2_asymptotic_2016_TrancheIV_v6-v1/AODSIM#dd153b5a-b5a2-11e6-8d5a-001e67abef8c 63/63
# ====================================================================================================
# Dataset: /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8/RunIISummer16DR80Premix-PUMoriond17_80X_mcRun2_asymptotic_2016_TrancheIV_v6-v1/AODSIM
# Num of blocks with no source files: 1/21
# Num of no source files: 135/2217
# Num of no source files by block:
#  /DYJetsToNuNu_PtZ-250To400_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8/RunIISummer16DR80Premix-PUMoriond17_80X_mcRun2_asymptotic_2016_TrancheIV_v6-v1/AODSIM#ffbadd4e-a6cb-11e6-babe-a0369f23d196 135/135
# ====================================================================================================
# Dataset: /MuGunFlatPt2to8/TTI2023Upg14D-FLATBS15PU200_FLATBS15_DES23_62_V1-v3/GEN-SIM-DIGI-RAW
# Num of blocks with no source files: 1/1
# Num of no source files: 1/4
# Num of no source files by block:
#  /MuGunFlatPt2to8/TTI2023Upg14D-FLATBS15PU200_FLATBS15_DES23_62_V1-v3/GEN-SIM-DIGI-RAW#5ac8e42a-aeaf-11e6-84ae-02163e01820e 1/4
# ====================================================================================================
# Dataset: /SingleNeutrino/RunIISummer16DR80-PUFlat0to50_magnetOff_80X_mcRun2_asymptotic_2016_TrancheIV_v6-v3/AODSIM
# Num of blocks with no source files: 3/9
# Num of no source files: 40/214
# Num of no source files by block:
#  /SingleNeutrino/RunIISummer16DR80-PUFlat0to50_magnetOff_80X_mcRun2_asymptotic_2016_TrancheIV_v6-v3/AODSIM#0509d3e2-b61a-11e6-b8e0-001e67abf094 2/2
#  /SingleNeutrino/RunIISummer16DR80-PUFlat0to50_magnetOff_80X_mcRun2_asymptotic_2016_TrancheIV_v6-v3/AODSIM#f614fea4-b55e-11e6-8d5a-001e67abef8c 6/6
#  /SingleNeutrino/RunIISummer16DR80-PUFlat0to50_magnetOff_80X_mcRun2_asymptotic_2016_TrancheIV_v6-v3/AODSIM#2f35aa6c-b541-11e6-84ae-02163e01820e 32/32
# ====================================================================================================

# %%
def search_deletions (block):
    url = 'https://cmsweb.cern.ch/phedex/datasvc/json/prod/deletions'
    params = {"block": block}
    deletions_info = requests.get(url=url, params= params, verify=False).content
    deletions_json = json.loads(deletions_info)
    return(deletions_json)

# %%
def write_deletions_json (site, deletions_json_list):
    filename = "nosource_blocks_deletions_jsons" + site + ".txt"

    with open(filename, "w") as f:
        deletions_json_list = map(str, deletions_json_list)
        f.write("\n".join(deletions_json_list))

# %%
deletions_json = []
for j in ns_files_info.blockname:
    deletion_json = search_deletions(j)
    deletions_json.append(deletion_json)

write_deletions_json(site, deletions_json)
